# %%
import pandas as pd
import numpy as np

# %%
# File path to the CSV file
file_path = "logs_cleaned_data.csv"

# Read the CSV without assuming a header
df = pd.read_csv(file_path)

# Assuming that the "Message" is in a specific column (adjust the index as needed)
# For example, let's assume column 1 (index 0) contains the messages
df.columns = ["Column_1", "Message", "Column_3"]  # Rename columns for clarity

# Define a function to categorize messages based on keywords
def categorize_status(message):
    message_lower = str(message).lower()
    if "error" in message_lower:
        return "critical"
    elif "warning" in message_lower:
        return "warning"
    elif "up" in message_lower:
        return "up"
    elif "down" in message_lower:
        return "down"
    elif "available" in message_lower:
        return "available"
    elif "denied" in message_lower:
        return "denied"
    elif "critical" in message_lower:
        return "critical"
    elif "started" in message_lower:
        return "started"
    else:
        return "unknown"

# Apply the function to create a new "Status Code" feature
df['Status Code'] = df['Message'].apply(categorize_status)

# Display the updated data with the new feature for verification
df1=df[['Message', 'Status Code']]

df1.head()
# Out:
#                                              Message Status Code
# 0              Agent 192.168.112.57 became available   available
# 1  Component DNS Server on Application NOC Infra ...    critical
# 2  Component Error and Warning Events: SMS Server...    critical
# 3           Sohar-Alreef - DIALUPTOHO Up 192.168.6.1          up
# 4  Error polling cloud volume prdz1rpabot1-osdisk...    critical

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      1559 non-null   object
#  1   Status Code  1559 non-null   object
# dtypes: object(2)
# memory usage: 24.5+ KB

# %%
# Get distinct values in the "Status Code" column
df1['Status Code'].unique()
# Out:
# array(['available', 'critical', 'up', 'down', 'unknown', 'warning'],
#       dtype=object)

# %%
# Define a mapping of status codes to clusters
status_to_cluster = {
    'unknown': 4,         # Cluster 4: Unknown States
    'available': 1,       # Cluster 1: Normal Operations
    'critical': 3,        # Cluster 3: Critical Issues
    'up': 1,              # Cluster 1: Normal Operations
    'down': 3,            # Cluster 3: Critical Issues
    'warning': 2          # Cluster 2: Warnings
}

# Apply the mapping to create a new "Cluster" column
df1['Cluster'] = df['Status Code'].map(status_to_cluster)

# Display the updated DataFrame with clusters for verification
df1[['Status Code', 'Cluster']].head(10)
# Out:
# C:\Users\senth\AppData\Local\Temp\ipykernel_16372\3227890412.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Cluster'] = df['Status Code'].map(status_to_cluster)
#   Status Code  Cluster
# 0   available        1
# 1    critical        3
# 2    critical        3
# 3          up        1
# 4    critical        3
# 5    critical        3
# 6    critical        3
# 7    critical        3
# 8    critical        3
# 9    critical        3

# %%
cluster_summary = df1.groupby('Cluster')['Status Code']
cluster_summary.value_counts()
# Out:
# Cluster  Status Code
# 1        up              127
#          available         8
# 2        warning          31
# 3        critical       1309
#          down             13
# 4        unknown          71
# Name: count, dtype: int64

# %%
# Sort the DataFrame by the "Cluster" column
df1_sorted = df1.sort_values(by='Cluster')

# %%
df1_sorted.head()
# Out:
#                                                 Message Status Code  Cluster
# 0                 Agent 192.168.112.57 became available   available        1
# 1215  Application "NOC Infra Critical Active Directo...          up        1
# 236   Component "Output Cache Total Hits (MAFVendor ...          up        1
# 512   Component Page Reads/sec on Application PRODSW...          up        1
# 904   Component "Active Directory Domain Services" f...          up        1

# %%
cluster_summary = df1_sorted.groupby('Cluster').agg({
    'Message': lambda x: ' | '.join(x),  # Combine messages with a separator
    'Status Code': lambda x: ', '.join(set(x))  # Unique status codes
}).reset_index()

# %%
for index, row in cluster_summary.iterrows():
    status_code = row['Status Code']
    print(f"Status Code: {status_code}")
    print(f"Messages: {row['Message']}")
    print()
# Out:
# Status Code: available, up
# Messages: Agent 192.168.112.57 became available | Application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is up 10.255.12.12 | Component "Output Cache Total Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is up 192.168.253.11 | Component Page Reads/sec on Application PRODSWSQL on Node ISNOCPRODSWSQL is Up 10.255.17.25 | Component "Active Directory Domain Services" for application "NOC Infra - Active Directory Domain Services Monitoring" on node "ISNOCPRDC01" is up 10.255.12.11 | Application "NOC Infra - Active Directory Domain Services Monitoring" on node "ISNOCPRDC01" is up 10.255.12.11 | Component "Metadata Cache Misses (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is up 192.168.253.11 | Node Greens-60F is Up. Customer Name: Choithrams Server Role: Greens Store Firewall Server Location: UAE - Retail Stores 10.168.110.100 | Component "DNS Server" for application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is up 10.255.12.12 | IS-DXB-HO-ESW04.intertecsys.com - GigabitEthernet1/0/22 · *** AI Thermal detector Reception - 172.20.133.11 *** Up 10.10.200.5 | Component "Page Reads/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is up 10.255.17.25 | Component DNS Server on Application NOC Infra Critical Active Directory Service Monitoring on Node ISNOCPRDC04 is Up 10.255.12.12 | Component DNS Server on Application NOC Infra Critical Active Directory Service Monitoring on Node ISNOCPRDC04 is Up 10.255.12.12 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is up 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is up 10.255.21.15 | Node Greens-60F is Up. Customer Name: Choithrams Server Role: Greens Store Firewall Server Location: UAE - Retail Stores 10.168.110.100 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is up 10.255.21.15 | Component DFS Namespace on Application NOC Infra - Active Directory DFS Namespace Service Monitoring on Node ISNOCPRDC01 is Up 10.255.12.11 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is up ADD WIDGETS 10.255.21.15 DONE EDITING NOC_TEST | Component "Output Cache Total Misses (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is up 192.168.253.11 | Component "URI Cache Misses (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is up 192.168.253.11 | Component "Top 10 active processes" for application "AIX" on node "AUHDWHDB" is up 10.190.40.63 | Component "Space on root (/) partition (MB)" for application "AIX" on node "AUHDWHDB" is up 10.190.40.63 | Component "Memory and Swap statistic (MB)" for application "AIX" on node "AUHDWHDB" is up 10.190.40.63 | Application "NOC Infra - Active Directory DFS Namespace Service Monitoring" on node "ISNOCPRDC01" is up 10.255.12.11 | Component "DFS Namespace" for application "NOC Infra - Active Directory DFS Namespace Service Monitoring" on node "ISNOCPRDC01" is up 10.255.12.11 | Application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is up 10.255.12.12 | Component "DNS Server" for application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is up 10.255.12.12 | Component "URI Cache Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is up 192.168.253.11 | Component "CPU statistic (%)" for application "AIX" on node "AUHDWHDB" is up 10.190.40.63 | Component "Lock Waits/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is up 10.255.17.25 | Component "DFS Namespace" for application "NOC Infra - Active Directory DFS Namespace Service Monitoring" on node "ISNOCPRDC01" is up 10.255.12.11 | 10.255.21.21 on node ISNOCDHAIVAPP01 Execute program D:\DND\Intertec\PostEvent.exe SolarWinds ALERT "The Ph ...
#
# Status Code: warning
# Messages: 10.10.200.201 troubleshooting steps, see Resolve malformed flow data warning. | Group Intertec Network is in a Warning state due to member status. IS-IPT-ESXi-01 is in a Warning state. | Group DEEM AIX Server is in a Warning state due to member status. 2 members are in a Warning state, 16 members are in a Unmanaged state. | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "DNS Server" for application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is in a warning state 10.255.12.12 | Application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is in a warning state 10.255.12.12 | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Component "Lock Waits/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state ADD WIDGETS DONE EDITING 10.255.21.15 NOC_TEST | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Group Intertec Server is in a Warning state due to member status. 1 member is in a Warning state, 6 members are in a Unmanaged state. | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "Lock Waits/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Component "Page Writes/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Group Intertec Network is in a Warning state due to member status. IS-DXB-HO-SRV-SW02.intertecsys.com is in a Warning state. | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component CPU statistic (%) on Application AIX on Node PRDERPDB1 is Warning 10.156.40.10 | Component "CPU statistic (%)" for application "AIX" on node "PRDERPDB1" is in a warning state 10.156.40.10 | Application "AIX" on node "PRDERPDB1" is in a warning state 10.156.40.10 | Group Intertec Network is in a Warning state due to member status. Intertec Perimter FW01 Firepower 2110 is in a Warning state.
#
# Status Code: down, critical
# Messages: Error polling cloud volume data_disk1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prd-z1-mwapp2os-25082022: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vda-PRD_Z1_ONBAPP2: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vda-PRD_Z1_SFTP1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vdb-PRD_Z1_PENT: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume data_disk2: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-PRD_Z1_ACCAPP: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-IDR-DB_OsDisk_1_f011d95c382a49968345d09d417e5945: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume data_disk3: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prd-data-node4_datadisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PRD-ICCSSRV1_DataDisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vdb-PRD_Z1_SFTP1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-PRD_Z1_MCSFTP: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-WAF1_OsDisk_1_69d60816fbf44e89b64ac7d9f39db038: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume DR-WAF1_OsDisk_1_4af9b201cdbf49c29960e144d0365529: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prdz1webapp3-osdisk-20210324-232522: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE1-PRD_Z1_CSAPP01: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vda-PRD_Z1_ONBAP_15July21-Restore-SR27735: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-PRD_Z1_CSAPP01: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-DEEMHRZ2: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-DATA-NODE3_OsDisk_1_b880772949504d8fb8d869e1157c64ee: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-NAME-NODE1_OsDisk_1_e6d7a8050e024d959628f4f98e3effa7: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PRD-NAME-NODE1_DataDisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prd-data-node2_datadisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-DEV_Z1_RPADEV1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-DATA-NODE2_OsDisk_1_1c4fa97442364e48a7f95f8c17d51437: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as Customize Page unknown. ADD WIDGETS DONE EDITING NOC_TEST Error polling cloud volume AUHAZDRAD1_OsDisk_1_e746c2932b3142f9bc2fbf4dfd107e39: Error polling volumes for cloud account DEEM_AZURE: Volume s ...
#
# Status Code: unknown
# Messages: Greens-60F has stopped responding (Request Timed Out) 10.168.110.100 | Application "SentinelOne Services" on node "ISPLBGLR1" is in an unknown state 192.168.12.21 | Component "SentinelOne Static Service" for application "SentinelOne Services" on node "ISPLBGLR1" is in an unknown state 192.168.12.21 | Component "Sentinel Agent" for application "SentinelOne Services" on node "ISPLBGLR1" is in an unknown state 192.168.12.21 | Component "SentinelOne Agent Log Processing Service" for application "SentinelOne Services" on node "ISPLBGLR1" is in an unknown state 192.168.12.21 | Component "Worker Process Statistic Monitor (DefaultAppPool)" for application "Microsoft IIS" on node "ITHDV7WEB02" is in a not running state 172.21.102.16 | Application "SentinelOne Services" on node "ispldevappsrv02" is in an unknown state 192.168.12.42 | Component "SentinelOne Static Service" for application "SentinelOne Services" on node "ispldevappsrv02" is in an unknown state 192.168.12.42 | Component "Sentinel Agent" for application "SentinelOne Services" on node "ispldevappsrv02" is in an unknown state 192.168.12.42 | Component "SentinelOne Agent Log Processing Service" for application "SentinelOne Services" on node "ispldevappsrv02" is in an unknown state 192.168.12.42 | Component "Application Pools" for application "Microsoft IIS" on node "mafweb01" is in a not running state 192.168.253.11 | Component "Worker Process Statistic Monitor (DefaultAppPool)" for application "Microsoft IIS" on node "ISNOCPRIVAPP01" is in a not running state 10.255.21.15 | 10.10.59.10 FW.intertecsys.com has a Received utilization of 1 % Customer Name: Intertec | Greens-60F is responding again. Response time is 14 milliseconds. 10.168.110.100 | Component "Worker Process Statistic Monitor (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in a not running state 192.168.253.11 | Component "World Wide Web Publishing Service" for application "Microsoft IIS" on node "ISNOCPRLDAPP02" is in an unknown state 10.255.15.26 | Application "AIX" on node "AUHDWHDB" is in an unknown state 10.190.40.63 | Greens-60F is responding again. Response time is 14 milliseconds. 10.168.110.100 | 192.168.99.1 IS-DXB-HO-CORE-SW.intertecsys.com has a Received utilization of 0 % Customer Name: Intertec Interface GigabitEthernet2/3/43 · *** Connected to FG-2 DC-CORE-VDOM-INSIDE Port1 *** for node IS-DXB-HO-CORE-SW.intertecsys.com has a transmitted utilization of 95 | Component "Output Cache Total Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Metadata Cache Misses (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Metadata Cache Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "File Cache Misses (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "File Cache Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Output Cache Current Memory Usage (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Maximum File Cache Memory Usage (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Current File Cache Memory Usage (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state ADD WIDGETS DONE EDITING 192.168.253.11 NOC_TEST | Component "Active Threads Count (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "URI Cache Hits (MAFVendor AppPool)" for application "Microsoft IIS" on node "mafweb01" is in an unknown state 192.168.253.11 | Component "Requests / Sec (MAFVendor  ...

# %%
# Filter rows with specific status codes: warning, down, critical
filtered_df = df1[df1['Status Code'].isin(['warning', 'down', 'critical'])]

# Sort the filtered DataFrame by the "Cluster" column
filtered_df_sorted = filtered_df.sort_values(by='Cluster')

# Group by Cluster and summarize
cluster_summary = filtered_df_sorted.groupby('Cluster').agg({
    'Message': lambda x: ' | '.join(x),  # Combine messages with a separator
    'Status Code': lambda x: ', '.join(set(x))  # Unique status codes
}).reset_index()

# %%
# Print the summary with status code as the header
for index, row in cluster_summary.iterrows():
    status_code = row['Status Code']
    print(f"Status Code: {status_code}")
    print(f"Messages: {row['Message']}")
    print()
# Out:
# Status Code: warning
# Messages: Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Group Intertec Network is in a Warning state due to member status. Intertec Perimter FW01 Firepower 2110 is in a Warning state. | 10.10.200.201 troubleshooting steps, see Resolve malformed flow data warning. | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "Lock Waits/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Component "Page Writes/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Group DEEM AIX Server is in a Warning state due to member status. 2 members are in a Warning state, 16 members are in a Unmanaged state. | Group Intertec Network is in a Warning state due to member status. IS-DXB-HO-SRV-SW02.intertecsys.com is in a Warning state. | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state ADD WIDGETS DONE EDITING 10.255.21.15 NOC_TEST | Component "Lock Waits/sec" for application "PRODSWSQL" on node "ISNOCPRODSWSQL" is in a warning state 10.255.17.25 | Component CPU statistic (%) on Application AIX on Node PRDERPDB1 is Warning 10.156.40.10 | Component "CPU statistic (%)" for application "AIX" on node "PRDERPDB1" is in a warning state 10.156.40.10 | Application "AIX" on node "PRDERPDB1" is in a warning state 10.156.40.10 | Component "DNS Server" for application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is in a warning state 10.255.12.12 | Application "NOC Infra Critical Active Directory Service Monitoring" on node "ISNOCPRDC04" is in a warning state 10.255.12.12 | Group Intertec Server is in a Warning state due to member status. 1 member is in a Warning state, 6 members are in a Unmanaged state. | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Microsoft System Center Configuration Manager Related Services" on node "ISDBPRCCM01" is in a warning state 172.20.110.61 | Group Intertec Network is in a Warning state due to member status. IS-IPT-ESXi-01 is in a Warning state. | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15 | Component "WMI Remote Ping" for application "Remote Ping to http://100.92.20.15 (TATA)" on node "ISNOCPRIVAPP01" is in a warning state 10.255.21.15
#
# Status Code: down, critical
# Messages: Error polling cloud volume prod-ftsapp1-20210125-155436: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vda-PRD_Z1_WEBAPP1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Component DFS Namespace on Application NOC Infra - Active Directory DFS Namespace Service Monitoring on Node ISNOCPRDC01 is Critical 10.255.12.11 | Error polling cloud volume prdz1asapp1-osdisk-20211130-154828: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume dev_vda-PRD_Z1_INTRAAPP: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-WAF2_OsDisk_1_362ca346f0a54920bfb2750c215aaf2b: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud account DEEM_AZURE: Azure VMs metrics poller has failed with access denied. | Node Greens-60F is Down. Customer Name: Choithrams Server Role: Greens Store Firewall Server Location: UAE - Retail Stores 10.168.110.100 | Error polling cloud volume prd-z1-mwapp1OS-25082022: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Component Error and Warning Events: SMS Server on Application Microsoft System Center Configuration Manager Related Services on Node ISDBPRCCM01 is Down 172.20.110.61 | Error polling cloud volume prd-data-node1_datadisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-DATA-NODE4_OsDisk_1_da67720f22814a22a90779fb9a434034: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prd-name-node2_datadisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-DATA-NODE1_OsDisk_1_b61f8b64afd342d5a6b8e68cb526ec8d: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-NAME-NODE2_OsDisk_1_cf6c62f224b7492cab3f051a19217441: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume prdz1rpabot1-osdisk-20240719-154903: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume DXBAZPRODAD01_DataDisk_0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume DXBAZPRODAD01_OsDisk_1_a911ea73172e4cf9951e4f0c609daece: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume AUHAZDRAD01_OsDisk_1_d44514e20e97492c9185fdd195d2655e: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PHYSICALDRIVE0-PRD_Z1_PBGSRV1: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume uat-data-ftsapp1-disk01: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-JUMP-SERVER_OsDisk_1_337c56107ba3496d9402ae4462c785e0: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume UAT-FTSAPP1-OS_DISK: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Component DNS Server on Application NOC Infra Critical Active Directory Service Monitoring on Node ISNOCPRDC04 is Critical 10.255.12.12 | Error polling cloud volume UAT_Z1_ACCAPP_OSDISK: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. | Error polling cloud volume PROD-MOBAPP1_OSDISK_COPY_JUN23: Error polling volumes for cloud account DEEM_AZURE: Volume status marked as unknown. Error polling cloud volume PRD-Z1-ACCDB_OsDisk_1_8562b2e1506444108912bf7a35364cda: Error polling volumes for cloud account DEEM_AZURE ...
